# %%
#image1
print("image1:Normal")
plt.imshow(image1)
plt.show()
plt.matshow(heatmap1)
plt.show()
plt.matshow(output1) 
plt.show()

#image 2
print("image2: Normal")
plt.imshow(image2)
plt.show()
plt.matshow(heatmap2)
plt.show()
plt.matshow(output2) 
plt.show()

print("image2: Covid")
#image 3
plt.imshow(image3)
plt.show()
plt.matshow(heatmap3)
plt.show()
plt.matshow(output3) 
plt.show()

print("image2: Covid")
#image 4
plt.imshow(image4)
plt.show()
plt.matshow(heatmap4)
plt.show()
plt.matshow(output4) 
plt.show()

#image5
print("image5:Lung Opacity")
plt.imshow(image5)
plt.show()
plt.matshow(heatmap5)
plt.show()
plt.matshow(output5) 
plt.show()

#image 6
print("image6: Lung Opacity")
plt.imshow(image6)
plt.show()
plt.matshow(heatmap6)
plt.show()
plt.matshow(output6) 
plt.show()

print("image7: Viral Pneumonia")
#image 7
plt.imshow(image7)
plt.show()
plt.matshow(heatmap7)
plt.show()
plt.matshow(output7) 
plt.show()

print("image8: Viral Pneumonia")
#image 8
plt.imshow(image8)
plt.show()
plt.matshow(heatmap8)
plt.show()
plt.matshow(output8) 
plt.show()
